# %% [markdown]
# We can also use osmanthus as a criteria for improving transcript assemblies.
# This include augmenting assembly by adding missing transcripts (decrease false negative)
# or removing transcripts that cannot fit into a tree (removing false-positive)
